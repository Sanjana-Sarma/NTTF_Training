# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjana-Sarma/NTTF_Training/blob/main/Exercise85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-87d7f82f-18b3-43aa-a7ee-5218401546ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87d7f82f-18b3-43aa-a7ee-5218401546ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df=pd.read_csv("Dummy_Dataset_StudentHappinessScore.csv")
df.head()
# Out:
#    Student ID  Year  Generosity  Life_Ladder  Perception_of_Academics
# 0           1  2019       1.892        1.258                    0.775
# 1           1  2020       1.953        1.243                    0.777
# 2           1  2021       1.936        1.320                    0.803
# 3           2  2019       2.026        1.226                    0.822
# 4           2  2020       1.945        1.206                    0.787

# %%
life_ladder = df['Life_Ladder']
perception_of_academics = df['Perception_of_Academics']
generosity = df['Generosity']

# %%
df.isnull().sum()
# Out:
# Student ID                 0
# Year                       0
# Generosity                 0
# Life_Ladder                0
# Perception_of_Academics    0
# dtype: int64

# %%
df.dtypes
# Out:
# Student ID                   int64
# Year                         int64
# Generosity                 float64
# Life_Ladder                float64
# Perception_of_Academics    float64
# dtype: object

# %%
df.describe()
# Out:
#        Student ID         Year  Generosity  Life_Ladder  \
# count   30.000000    30.000000   30.000000    30.000000
# mean     5.500000  2020.000000    1.902133     1.168333
# std      2.921384     0.830455    0.132700     0.081885
# min      1.000000  2019.000000    1.584000     0.980000
# 25%      3.000000  2019.000000    1.852500     1.111250
# 50%      5.500000  2020.000000    1.898500     1.185000
# 75%      8.000000  2021.000000    1.951000     1.224750
# max     10.000000  2021.000000    2.209000     1.320000
#
#        Perception_of_Academics
# count                30.000000
# mean                  0.750967
# std                   0.067711
# min                   0.577000
# 25%                   0.735750
# 50%                   0.774500
# 75%                   0.789250
# max                   0.851000

# %%
columns = [life_ladder, perception_of_academics, generosity]
column_labels = ['Life Ladder', 'Perception of Academics', 'Generosity']

# Create separate 3D scatter plots for each column
for i, column in enumerate(columns):
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    # Create the 3D scatter plot with continuous color mapping
    scatter = ax.scatter(life_ladder, perception_of_academics, generosity, c=column, cmap='viridis')

    # Add color bar to indicate the mapping of the current column's values
    cbar = fig.colorbar(scatter, ax=ax, label=column_labels[i])

    ax.set_xlabel('Life Ladder')
    ax.set_ylabel('Perception of Academics')
    ax.set_zlabel(column_labels[i])
    ax.set_title(f'Student Happiness Visualization - {column_labels[i]}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# This visualization can be used to identify clusters of data points. The points in each cluster will have the same color. This can be helpful for understanding the data and for selecting appropriate parameters for clustering algorithms.
# When you color-code data points in a scatter plot based on a variable, it can help you visually identify clusters or patterns in the data. Points with similar colors tend to have similar values for the chosen variable.
