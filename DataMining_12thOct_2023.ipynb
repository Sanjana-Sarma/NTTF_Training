# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjana-Sarma/NTTF_Training/blob/main/DataMining_12thOct_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-59c23fb7-4e1d-4ad2-99e5-af3511bd1b2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59c23fb7-4e1d-4ad2-99e5-af3511bd1b2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
housing_df=pd.read_csv(io.BytesIO(uploaded["WestRoxbury.csv"]))
housing_df.head(5)
# Out:
#    TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  FLOORS   \
# 0         344.2  4330       9965      1880         2436         1352      2.0
# 1         412.6  5190       6590      1945         3108         1976      2.0
# 2         330.1  4152       7500      1890         2294         1371      2.0
# 3         498.6  6272      13773      1957         5032         2608      1.0
# 4         331.5  4170       5000      1910         2370         1438      2.0
#
#    ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE REMODEL
# 0      6          3          1          1        1          0    None
# 1     10          4          2          1        1          0  Recent
# 2      8          4          1          1        1          0    None
# 3      9          5          1          1        1          1    None
# 4      7          3          2          0        1          0    None

# %%
housing_df=housing_df.rename(columns={'TOTAL VALUE':'TOTAL_VALUE'})
housing_df.columns=[s.strip().replace(' ','_') for s in housing_df.columns]
housing_df
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0           344.2  4330      9965      1880        2436         1352     2.0
# 1           412.6  5190      6590      1945        3108         1976     2.0
# 2           330.1  4152      7500      1890        2294         1371     2.0
# 3           498.6  6272     13773      1957        5032         2608     1.0
# 4           331.5  4170      5000      1910        2370         1438     2.0
# ...           ...   ...       ...       ...         ...          ...     ...
# 5797        404.8  5092      6762      1938        2594         1714     2.0
# 5798        407.9  5131      9408      1950        2414         1333     2.0
# 5799        406.5  5113      7198      1987        2480         1674     2.0
# 5800        308.7  3883      6890      1946        2000         1000     1.0
# 5801        447.6  5630      7406      1950        2510         1600     2.0
#
# ...

# %%
housing_df.loc[0:3]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None
# 3      9         5          1          1        1          1    None

# %%
housing_df.iloc[0:4]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 0        344.2  4330      9965      1880        2436         1352     2.0
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0    None
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0    None
# 3      9         5          1          1        1          1    None

# %%
housing_df.iloc[4][0:10]
# Out:
# TOTAL_VALUE    331.5
# TAX             4170
# LOT_SQFT        5000
# YR_BUILT        1910
# GROSS_AREA      2370
# LIVING_AREA     1438
# FLOORS           2.0
# ROOMS              7
# BEDROOMS           3
# FULL_BATH          2
# Name: 4, dtype: object

# %%
housing_df.iloc[4:5,0:10]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH
# 4      7         3          2

# %%
pd.concat([housing_df.iloc[4:6,0:2], housing_df.iloc[4:6,4:6]], axis=1)
# Out:
#    TOTAL_VALUE   TAX  GROSS_AREA  LIVING_AREA
# 4        331.5  4170        2370         1438
# 5        337.4  4244        2124         1060

# %%
housing_df.iloc[:, 0:1]
# Out:
#       TOTAL_VALUE
# 0           344.2
# 1           412.6
# 2           330.1
# 3           498.6
# 4           331.5
# ...           ...
# 5797        404.8
# 5798        407.9
# 5799        406.5
# 5800        308.7
# 5801        447.6
#
# [5802 rows x 1 columns]

# %%
housing_df.TOTAL_VALUE
# Out:
# 0       344.2
# 1       412.6
# 2       330.1
# 3       498.6
# 4       331.5
#         ...
# 5797    404.8
# 5798    407.9
# 5799    406.5
# 5800    308.7
# 5801    447.6
# Name: TOTAL_VALUE, Length: 5802, dtype: float64

# %%
print("number of rows: ", len(housing_df['TOTAL_VALUE']))
# Out:
# number of rows:  5802

# %%
print("average of total values: ", housing_df['TOTAL_VALUE'].mean())
# Out:
# average of total values:  392.6857149258877

# %%
housing_df.describe()
# Out:
#        TOTAL_VALUE           TAX      LOT_SQFT     YR_BUILT   GROSS_AREA  \
# count  5802.000000   5802.000000   5802.000000  5802.000000  5802.000000
# mean    392.685715   4939.485867   6278.083764  1936.744916  2924.842123
# std      99.177414   1247.649118   2669.707974    35.989910   883.984726
# min     105.000000   1320.000000    997.000000     0.000000   821.000000
# 25%     325.125000   4089.500000   4772.000000  1920.000000  2347.000000
# 50%     375.900000   4728.000000   5683.000000  1935.000000  2700.000000
# 75%     438.775000   5519.500000   7022.250000  1955.000000  3239.000000
# max    1217.800000  15319.000000  46411.000000  2011.000000  8154.000000
#
#        LIVING_AREA       FLOORS        ROOMS     BEDROOMS    FULL_BATH  \
# count  5802.000000  5802.000000  5802.000000  5802.000000  5802.000000
# mean   1657.065322     1.683730     6.994829     3.230093     1.296794
# std     540.456726     0.444884     1.437657     0.846607     0.522040
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
housing_df.sample(5)
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 4250        325.0  4088      4026      1930        2934         1330     1.0
# 3425        364.1  4580      5037      1930        2905         1755     2.5
# 1528        323.6  4070      4050      1920        1910          984     2.0
# 2369        443.7  5581      5225      1930        2448         1504     2.0
# 18          330.7  4160      5000      1910        2408         1470     2.0
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 4250      7         3          2          0        1          0     Old
# 3425      7         3          2          1        1          1    None
# 1528      6         3          1          0        1          1    None
# 2369      7         3          1          1        1          1    None
# 18        7         3          1          0        1          0    None

# %%
weights=[0.9 if rooms>10 else 0.01 for rooms in housing_df.ROOMS]
housing_df.sample(5,weights=weights)
# Out:
#       TOTAL_VALUE    TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS  \
# 3837        476.1   5989      3620      1932        4118         3058     2.0
# 4051        626.3   7878     12169      1913        5751         2942     2.0
# 5162        341.4   4294      4000      1928        2573         1544     2.0
# 3488        771.0   9699     27408      1914        5786         3050     2.0
# 2695        823.7  10362     28900      1935        5499         2925     2.0
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 3837     11         5          2          2        1          1  Recent
# 4051     12         6          1          2        1          1     Old
# 5162      7         3          1          0        1          0     Old
# 3488     12         4          3          0        1          0  Recent
# 2695     12         5          2          1        1          2    None

# %%
housing_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
housing_df.dtypes
# Out:
# TOTAL_VALUE    float64
# TAX              int64
# LOT_SQFT         int64
# YR_BUILT         int64
# GROSS_AREA       int64
# LIVING_AREA      int64
# FLOORS         float64
# ROOMS            int64
# BEDROOMS         int64
# FULL_BATH        int64
# HALF_BATH        int64
# KITCHEN          int64
# FIREPLACE        int64
# REMODEL         object
# dtype: object

# %%
housing_df.REMODEL=housing_df.REMODEL.astype('category')

# %%
housing_df.REMODEL.cat.categories
# Out:
# Index(['None', 'Old', 'Recent'], dtype='object')

# %%
housing_df.REMODEL.dtype
# Out:
# CategoricalDtype(categories=['None', 'Old', 'Recent'], ordered=False)

# %%
housing_df=pd.get_dummies(housing_df, prefix_sep='_', drop_first=True)
housing_df.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL_Old', 'REMODEL_Recent'],
#       dtype='object')

# %%
housing_df.loc[:, 'REMODEL_Old':'REMODEL_Recent'].head(5)
# Out:
#    REMODEL_Old  REMODEL_Recent
# 0            0               0
# 1            0               1
# 2            0               0
# 3            0               0
# 4            0               0

# %%
missingRows=housing_df.sample(10).index

# %%
housing_df.loc[missingRows, 'BEDROOMS']=np.nan

# %%
print("Number of rows with valid BEDROOMS value after setting to NAN: ", housing_df['BEDROOMS'].count())
# Out:
# Number of rows with valid BEDROOMS value after setting to NAN:  5792

# %%
reduced_df=housing_df.dropna()
print("Number of rows after removing rows with missing values: ", len(reduced_df))
# Out:
# Number of rows after removing rows with missing values:  5792

# %%
medianBedrooms=housing_df['BEDROOMS'].median()
housing_df.BEDROOMS=housing_df.BEDROOMS.fillna(value=medianBedrooms)
print("Number of rows with valid BEDROOMS after removing NA values: ", housing_df['BEDROOMS'].count())
# Out:
# Number of rows with valid BEDROOMS after removing NA values:  5802

# %%
#how to normalize or standardize
